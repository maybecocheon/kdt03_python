# %%
# !python --version
# Out:
# Python 3.12.10

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# 마크다운으로 설명 적기 가능
# * 앞에 숫자도 달았어
# * ctrl + , => line numbers

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
1 + 2
# Out:
# 3

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
a / b
# Out:
# 0.5

# %%
a // b
# Out:
# 0

# %% [markdown]
# * 자바 같은 c 계열 언어는 1 / 2 하면 0이 나옴 (결과는 정수)
# * 파이썬의 경우 0.5(실수 값)이 나옴

# %%
5**2
# Out:
# 25

# %% [markdown]
# 자바의 경우 5의 제곱은
# * 5*5
# * Math.pow(5, 2)

# %%
1 + (2 * 3)
# Out:
# 7

# %% [markdown]
# * 명시적으로 괄호 써 주는 게 좋음
# * 파이썬의 경우 +, -를 활용한 단항 연산자가 곱셈 연산자보다 우선순위 높기 때문

# %%
lst = [1, 3.14, 'hello', True]
lst
# Out:
# [1, 3.14, 'hello', True]

# %% [markdown]
# * 자바는 int, double 등 기본형은 Object가 아님
# * 파이썬은 모든 것이 Object

# %%
type(1)
# Out:
# int

# %%
for l in lst:
    print(type(l), l)
# Out:
# <class 'int'> 1
# <class 'float'> 3.14
# <class 'str'> hello
# <class 'bool'> True

# %%
a = 100_000_000
a
# Out:
# 100000000

# %%
1e5
# Out:
# 100000.0

# %%
3.14e-3
# Out:
# 0.00314

# %% [markdown]
# e는 n.0에서의 점에 해당함
# * e 뒤에 양수 적으면 점이 뒤로 이동하고
# * e 뒤에 음수 적으면 점이 앞으로 이동함

# %%
msg = "hello, world!"
msg
# Out:
# 'hello, world!'

# %%
type(msg)
# Out:
# str

# %%
msg = 1
type(msg)
# Out:
# int

# %%
msg = [1, 3.14, 'hello', True]
msg
# Out:
# [1, 3.14, 'hello', True]

# %%
print("hello, \nworld!")
# Out:
# hello,
# world!

# %%
'hello, ' + "world!"
# Out:
# 'hello, world!'

# %% [markdown]
# * 홑따옴표와 쌍따옴표 구분 x

# %%
r'\n{a}, {b}'
# Out:
# '\\n{a}, {b}'

# %% [markdown]
# * raw 문자열 리터럴은 입력한 값 그대로 전달

# %%
f'{a}, {b}'
# Out:
# '100000000, 2'

# %% [markdown]
# * 자바처럼 String.format 하지 않아도 f 써서 형식을 만들 수 있음

# %%
def div(a: int, b: int) -> float:
    return a / b

# %%
c = div(1, 2)
type(c)
# Out:
# float

# %% [markdown]
# * 변수명: 타입 형식으로 타입을 명시적으로 기재해 줄 수 있음
# * 함수명 -> 타입 형식으로 타입을 명시적으로 기재해 줄 수 있음

# %%
a = 1
b = 2
a, b = b, a # 파이썬 스타일로 swap 하기
a, b
# Out:
# (2, 1)

# %% [markdown]
# * swap 시 temp 변수에 따로 저장할 필요 없음
# * 대입문을 이용해 바로 swap 가능

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
