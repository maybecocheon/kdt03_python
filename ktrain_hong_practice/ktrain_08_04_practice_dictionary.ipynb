# %%
# 실습 1: 1부터 100 사이의 난수를 20개 생성하여 리스트에 저장
import random

# 1) 내포 표기 없이
# # 빈 리스트 생성
# random_numbers = []

# # 난수를 20개 생성하여 리스트에 추가
# for _ in range(20):
#     random_numbers.append(random.randint(1, 100))

# 2) 리스트 내포 표기
random_numbers = [random.randint(1, 100) for _ in range(20)]

# 저장된 리스트 출력
print(f"난수 생성 = {random_numbers}")
# Out:
# 난수 생성 = [64, 80, 35, 42, 85, 38, 77, 45, 21, 82, 69, 86, 41, 56, 47, 86, 57, 73, 62, 76]

# %%
# 실습 2: s1, s2, ..., s20 형태의 학번 리스트 생성

# 빈 리스트 생성
string_list = []

# s1 ~ s20 생성하여 리스트에 추가
for i in range(1, 21):
    string_list.append(f"s{i}")

# 저장된 리스트 출력
print(f"sno 리스트 = {string_list}")
# Out:
# sno 리스트 = ['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20']

# %%
# 실습 3: 학번과 점수를 키-값으로 갖는 딕셔너리 생성

students = string_list
scores = random_numbers

# 딕셔너리 생성
score_dic = {students[i]: scores[i] for i in range(20)}

# 결과 출력
print(f"학번과 점수 딕셔너리 = {score_dic}")
# Out:
# 학번과 점수 딕셔너리 = {'s1': 20, 's2': 47, 's3': 16, 's4': 27, 's5': 99, 's6': 78, 's7': 31, 's8': 100, 's9': 12, 's10': 55, 's11': 44, 's12': 12, 's13': 15, 's14': 56, 's15': 89, 's16': 2, 's17': 21, 's18': 98, 's19': 9, 's20': 35}

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
# 실습 4: 점수를 기준으로 내림차순 정렬한 튜플 리스트 생성

# 딕셔너리의 (학번, 점수) 쌍을 튜플로 정렬
sorted_scores = sorted(score_dic.items(), key=lambda item: item[1], reverse=True)   # item은 items() 함수가 반환(=키와 값 튜플을 요소로 갖는 리스트)하는 리스트의 요소 하나(=키와 값 튜플 한 개)

# 결과 출력
print(f"점수로 정렬된 튜플 리스트 = {sorted_scores}")
# Out:
# 점수로 정렬된 튜플 리스트 = [('s8', 100), ('s5', 99), ('s18', 98), ('s15', 89), ('s6', 78), ('s14', 56), ('s10', 55), ('s2', 47), ('s11', 44), ('s20', 35), ('s7', 31), ('s4', 27), ('s17', 21), ('s1', 20), ('s3', 16), ('s13', 15), ('s9', 12), ('s12', 12), ('s19', 9), ('s16', 2)]

# %%
# 실습 5: 정렬된 리스트를 다시 딕셔너리로 변환

sorted_score_dic = dict(sorted_scores)

# 결과 출력
print(f"점수로 정렬된 딕셔너리 = {sorted_score_dic}")
# Out:
# 점수로 정렬된 딕셔너리 = {'s8': 100, 's5': 99, 's18': 98, 's15': 89, 's6': 78, 's14': 56, 's10': 55, 's2': 47, 's11': 44, 's20': 35, 's7': 31, 's4': 27, 's17': 21, 's1': 20, 's3': 16, 's13': 15, 's9': 12, 's12': 12, 's19': 9, 's16': 2}

# %%
# 실습 6: 상위 5개의 학생만 추출하여 딕셔너리로 저장

top_5 = dict(sorted_scores[:5])

# 결과 출력
print(f"상위 5개 = {top_5}")
# Out:
# 상위 5개 = {'s8': 100, 's5': 99, 's18': 98, 's15': 89, 's6': 78}

# %%
# 실습 7: 딕셔너리 → 튜플 리스트 변환 (key, value 쌍으로)

score_list = list(score_dic.items())

# 결과 출력
print(f"리스트로 변환된 딕셔너리: {score_list}")
# Out:
# 리스트로 변환된 딕셔너리: [('s1', 20), ('s2', 47), ('s3', 16), ('s4', 27), ('s5', 99), ('s6', 78), ('s7', 31), ('s8', 100), ('s9', 12), ('s10', 55), ('s11', 44), ('s12', 12), ('s13', 15), ('s14', 56), ('s15', 89), ('s16', 2), ('s17', 21), ('s18', 98), ('s19', 9), ('s20', 35)]

# %%
# 실습 8: enumerate를 활용하여 딕셔너리를 새로운 딕셔너리로 변환

transformed_score_dic = {i: (key, value) for i, (key, value) in enumerate(score_dic.items(), start=1)}

# 결과 출력
print(f"변환된 딕셔너리: {transformed_score_dic}")
# Out:
# 변환된 딕셔너리: {1: ('s1', 20), 2: ('s2', 47), 3: ('s3', 16), 4: ('s4', 27), 5: ('s5', 99), 6: ('s6', 78), 7: ('s7', 31), 8: ('s8', 100), 9: ('s9', 12), 10: ('s10', 55), 11: ('s11', 44), 12: ('s12', 12), 13: ('s13', 15), 14: ('s14', 56), 15: ('s15', 89), 16: ('s16', 2), 17: ('s17', 21), 18: ('s18', 98), 19: ('s19', 9), 20: ('s20', 35)}
