# %% [markdown]
# # 모듈과 패키지
# ## 모듈

# %%
"""두 값의 최솟값과 최댓값 구하기"""

def min_max2(a, b):
    """a와 b의 최솟값과 최댓값을 구하여 리턴"""
    return (a, b) if a < b else (b, a)

n1 = int(input('정수 n1：'))
n2 = int(input('정수 n2：'))

minimum, maximum = min_max2(n1, n2)
print('최솟값은', minimum, '이고 최댓값은', maximum, '입니다.')
# Out:
# 최솟값은 4 이고 최댓값은 5 입니다.

# %%
# __name__ == __main__ 구문 없으면 임포트한 파일의 구문 모두 가져옴
"""min_max2모듈의 min_max2함수 호출하기"""

import min_max2     # min_max2.py 코드를 가져오는 것

x = float(input('실수 x：'))
y = float(input('실수 y：'))

mini, maxi = min_max2.min_max2(x, y)
print('최솟값은', mini, '입니다.')
print('최댓값은', maxi, '입니다.')
# Out:
# 최솟값은 1.2 입니다.
# 최댓값은 2.5 입니다.

# %%
"""min_max 모듈의 함수 호출하기"""

import min_max

x = float(input('실수 x：'))
y = float(input('실수 y：'))
z = float(input('실수 z：'))

print('x와 y의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(x, y)))
print('y와 z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(y, z)))
print('x와 z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(x, z)))
print('x, y, z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max3(x, y, z)))
# Out:
# x와 y의 최솟값은 1.2이고, 최댓값은 2.3입니다.
# y와 z의 최솟값은 2.3이고, 최댓값은 3.3입니다.
# x와 z의 최솟값은 1.2이고, 최댓값은 3.3입니다.
# x, y, z의 최솟값은 1.2이고, 최댓값은 3.3입니다.

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\kdt03_python\\.venv', '', 'c:\\kdt03_python\\.venv\\Lib\\site-packages']

# %%
# p. 475 단순명 같아도 모듈 이름 다르면 구분 가능 => FQN 사용
import min_max
import min_max2

min_max.min_max2
min_max2.min_max2

# %%
# p. 477
import min_max as mm            # 모듈명 별칭
from min_max2 import min_max2   # 1) 임포트하여 단순명으로만 사용 가능 2) * 쓰면 모든 객체 단순명으로 접근 가능

mm.min_max2
min_max2
